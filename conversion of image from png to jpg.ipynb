# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2
png_img = cv2.imread('first_image.png')
plt.imshow(image)
plt.show()

# %%
jpg_img = cv2.cvtColor(png_img, cv2.COLOR_RGBA2BGR)

# %%
cv2.imwrite('first_image.png',jpg_img)
# Out:
# True
